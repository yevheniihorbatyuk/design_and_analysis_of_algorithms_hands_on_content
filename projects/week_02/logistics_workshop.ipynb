# %% [markdown]
#   # Практичний воркшоп: Побудова логістичної системи з нуля
#
#
#
#   **Сценарій:** Ми — логістична компанія, яка має доставити 15 замовлень по Київській області з 3 складів, використовуючи 3 вантажівки різної місткості.
#
#
#
#   **Наша мета:** Побудувати повний цикл оптимізації: від отримання матриці реальних дорожніх відстаней до візуалізації оптимальних маршрутів на карті.
#
#
#
#   ### Архітектура нашого рішення
#
#   ```mermaid
#
# [ Вхідні дані: CSV з точками ]
#
#       ↓
#
# [ Крок 1: Матриця відстаней (OSRM) ]
#
#       ↓
#
# [ Крок 2: VRP Оптимізація (VROOM) ]
#
#       ↓
#
# [ Крок 3: Візуалізація та аналітика (Folium, Pandas) ]
#
#   ```

# %%
# !pip install requests folium
# Out:
# Requirement already satisfied: requests in /root/goit/.venv/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: folium in /root/goit/.venv/lib/python3.12/site-packages (0.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/goit/.venv/lib/python3.12/site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /root/goit/.venv/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/goit/.venv/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/goit/.venv/lib/python3.12/site-packages (from requests) (2025.8.3)
# Requirement already satisfied: branca>=0.6.0 in /root/goit/.venv/lib/python3.12/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /root/goit/.venv/lib/python3.12/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /root/goit/.venv/lib/python3.12/site-packages (from folium) (2.3.3)
# Requirement already satisfied: xyzservices in /root/goit/.venv/lib/python3.12/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/goit/.venv/lib/python3.12/site-packages (from jinja2>=2.9->folium) (3.0.3)

# %%
# =============================================================================
# Клітинка 1: Налаштування середовища та імпорти
# =============================================================================
import pandas as pd
import requests
import json
import folium
from folium.plugins import HeatMap
import time
from datetime import datetime, timedelta

# Налаштування Pandas для кращого відображення
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 120)

# URL до наших локальних сервісів (запущених через Docker Compose)
OSRM_URL = "http://localhost:5000"
VROOM_URL = "http://139.162.190.110:3000/optimize"

print("✅ Середовище та змінні налаштовано.")
# Out:
# ✅ Середовище та змінні налаштовано.

# %% [markdown]
#   ## Підготовка: Запускаємо інфраструктуру
#
#
#
#   Перш ніж почати, нам потрібно запустити два ключові сервіси: **OSRM** (для розрахунку маршрутів) та **VROOM** (для VRP оптимізації).
#
#
#
# **Інструкція:**
#
# 1. **Встановіть Docker та Docker Compose.**
#
# 2. **Завантажте карту:** Завантажте файл `ukraine-latest.osm.pbf` з [Geofabrik](https://download.geofabrik.de/europe/ukraine.html) і покладіть його в папку `data/osrm_data/`.
#
# 3. **Підготуйте OSRM дані:** В терміналі, у корені проєкту, виконайте наступні команди. **Це може зайняти 10-30 хвилин і потребувати >16GB RAM!**
#
# ```bash
#
# # Крок 1: Extract (витягнення графу доріг)
#
# docker run -t -v "${PWD}/data/osrm_data:/data" osrm/osrm-backend osrm-extract -p /opt/car.lua /data/ukraine-latest.osm.pbf
#
# # Крок 2: Partition and Customize (для MLD алгоритму)
#
# docker run -t -v "${PWD}/data/osrm_data:/data" osrm/osrm-backend osrm-partition /data/ukraine-latest.osrm
#
# docker run -t -v "${PWD}/data/osrm_data:/data" osrm/osrm-backend osrm-customize /data/ukraine-latest.osrm
#
# ```
#
# 4. **Запустіть сервіси:**
#
#    ```bash
#
#    docker-compose up -d
#
#    ```
#
# 5. **Перевірте, чи сервіси працюють:**
#
#    - OSRM: [http://localhost:5000](http://localhost:5000)
#
#    - VROOM: [http://localhost:3000](http://localhost:3000)

# %%
# =============================================================================
# Клітинка 2: Завантаження та підготовка вхідних даних
# =============================================================================
# Завантажуємо дані з CSV
try:
    points_df = pd.read_csv('data/points.csv')
    depots_df = points_df[points_df['type'] == 'depot'].reset_index(drop=True)
    jobs_df = points_df[points_df['type'] == 'delivery'].reset_index(drop=True)
    print("✅ Дані успішно завантажено:")
    print("\nСклади (депо):")
    print(depots_df)
    print("\nТочки доставки (замовлення):")
    print(jobs_df)
except FileNotFoundError:
    print("❌ Помилка: файл 'data/points.csv' не знайдено. Будь ласка, створіть його.")

# Функція для перетворення часу у секунди від півночі
def time_to_seconds(time_str):
    h, m = map(int, time_str.split(':'))
    return h * 3600 + m * 60
# Out:
# ✅ Дані успішно завантажено:
#
# Склади (депо):
#     type        name      lat      lon  demand time_window_start time_window_end
# 0  depot  Київ-Центр  50.4501  30.5234       0             09:00           18:00
# 1  depot     Бровари  50.5116  30.8357       0             09:00           18:00
# 2  depot     Вишневе  50.3951  30.3621       0             09:00           18:00
#
# Точки доставки (замовлення):
#         type         name      lat      lon  demand time_window_start time_window_end
# 0   delivery       Фастів  50.0768  29.9182       5             10:00           12:00
# 1   delivery    Васильків  50.1772  30.3155       7             09:00           11:00
# 2   delivery       Обухів  50.1264  30.6206       4             11:00           14:00
# 3   delivery    Бориспіль  50.3551  30.9542      10             09:00           18:00
# 4   delivery       Ірпінь  50.5173  30.2483       8             13:00           16:00
# 5   delivery         Буча  50.5459  30.2223       6             13:00           16:00
# 6   delivery     Вишгород  50.5841  30.4939       9             10:00           13:00
# 7   delivery  Біла Церква  49.7981  30.1161      12             10:00           15:00
# 8   delivery    Переяслав  50.0700  31.4500       5             14:00           17:00
# 9   delivery       Сквира  49.7328  29.6508       3             09:00           12:00
# 10  delivery     Кагарлик  49.8519  30.8066       4             12:00           15:00
# 11  delivery    Миронівка  49.6644  31.0069       6             11:00           14:00
# 12  delivery       Боярка  50.3276  30.2898       8             09:00           13:00
# 13  delivery     Українка  50.1481  30.7444       7             14:00           18:00

# %% [markdown]
#   ## Крок 1: Розрахунок матриці відстаней та часу
#
#
#
#   **Задача:** Отримати точні час та відстань по дорогах між усіма нашими точками (складами та клієнтами). Це "паливо" для будь-якого VRP-оптимізатора.
#
#
#
#   **Інструмент:** **OSRM (Open Source Routing Machine)**. Це надзвичайно швидкий рушій для маршрутизації, який використовує алгоритм **Contraction Hierarchies (CH)** для досягнення мілісекундних відповідей на запити.

# %%
import numpy as np

# %%
# =============================================================================
# Клітинка 3: Запит до OSRM для отримання матриці
# =============================================================================
def get_osrm_matrix(points):
    """Отримує матрицю відстаней та часу від OSRM."""
    locations = ";".join([f"{lon},{lat}" for lon, lat in points[['lon', 'lat']].values])
    url = f"{OSRM_URL}/table/v1/driving/{locations}?annotations=duration,distance"
    
    try:
        response = requests.get(url, timeout=30)
        response.raise_for_status()
        data = response.json()
        
        if data['code'] == 'Ok':
            print("✅ Матрицю відстаней та часу успішно отримано від OSRM.")
            return np.array(data['durations']), np.array(data['distances'])
        else:
            print(f"❌ Помилка OSRM: {data['message']}")
            return None, None
    except requests.exceptions.RequestException as e:
        print(f"❌ Не вдалося підключитися до OSRM: {e}")
        print("   Переконайтеся, що Docker контейнери запущені.")
        return None, None

# Об'єднуємо всі точки для запиту до OSRM
all_points = pd.concat([depots_df, jobs_df], ignore_index=True)
durations_matrix, distances_matrix = get_osrm_matrix(all_points)

if durations_matrix is not None:
    # Конвертуємо у хвилини для кращої читабельності
    durations_df = pd.DataFrame(durations_matrix / 60, 
                                index=all_points['name'], 
                                columns=all_points['name'])
    print("\nМатриця часу в дорозі (хвилини):")
    print(durations_df.round(1))
# Out:
# ✅ Матрицю відстаней та часу успішно отримано від OSRM.
#
# Матриця часу в дорозі (хвилини):
# name         Київ-Центр  Бровари  Вишневе  Фастів  Васильків  Обухів  Бориспіль  Ірпінь   Буча  Вишгород  Біла Церква  \
# name
# Київ-Центр          0.0     37.8     26.6    72.5       43.4    48.4       42.4    35.1   40.1      31.1         74.2
# Бровари            34.7      0.0     57.0    99.2       70.1    70.7       24.9    69.8   74.3      54.6        100.9
# Вишневе            28.1     57.9      0.0    68.1       38.9    52.7       56.2    30.1   35.2      44.6         69.7
# Фастів             75.0     99.7     70.7     0.0       39.9    71.8       97.9    77.0   79.6      98.2         35.8
# Васильків          47.1     71.8     42.9    39.9        0.0    35.5       70.0    62.4   67.4      70.3         42.0
# Обухів             50.3     72.3     56.3    72.0       35.7     0.0       68.1    75.9   80.9      76.6         73.4
# Бориспіль          41.8     25.5     56.4    98.6       69.5    66.5        0.0    73.4   78.4      66.7        100.3
# Ірпінь             37.0     71.1     28.6    78.5       60.9    73.3       74.4     0.0    6.7      37.0         91.7
# Буча               41.6     74.8     33.6    79.6       65.9    78.3       79.4     6.9    0.0      37.2         96.7
# Вишгород           29.6     56.4     43.2    98.7       69.5    75.8       66.5    37.3   37.2       0.0        100.3
# Біла Церква        77.7    102.4     73.5    36.4       43.0    72.6      100.7    93.0   98.0     100.9          0.0
# Переяслав          90.9     72.2    105.5   147.7      118.6   115.6       50.3   122.4  127.5     115.8        149.3
# Сквира            130.7    155.4    126.4    75.3       96.0   125.6      153.6   146.0  151.0     153.9         57.9
# Кагарлик           86.3    108.3     92.4   104.2       67.9    44.4      104.1   111.9  116.9     112.7         84.7
# Миронівка         114.5    136.5    120.6   122.1       96.1    72.6      132.3   140.1  145.1     140.9         88.0
# Боярка             40.8     68.1     17.1    55.8       26.9    46.9       66.4    40.8   46.1      58.9         57.4
# Українка           52.7     74.6     59.1    85.2       48.8    20.3       70.4    78.6   83.6      79.0         82.1
#
# name         Переяслав  Сквира  Кагарлик  Миронівка  Боярка  Українка
# name
# Київ-Центр        91.5   127.6      85.0      113.3    38.3      51.6
# Бровари           71.7   154.3     107.3      135.5    66.8      73.9
# Вишневе          105.2   123.1      89.3      117.6    17.1      55.9
# Фастів           146.9    75.2     104.0      123.0    56.1      82.2
# Васильків        119.1    95.4      67.7       96.0    28.5      48.8
# Обухів           117.1   126.8      44.3       72.6    46.8      20.4
# Бориспіль         50.3   153.7     103.1      131.4    66.1      69.7
# Ірпінь           123.5   145.1     109.9      138.2    40.8      76.5
# Буча             128.5   150.1     114.9      143.2    45.8      81.5
# Вишгород         115.6   153.7     112.4      140.7    57.6      79.0
# Біла Церква      149.7    55.4      85.2       89.8    58.8      81.7
# Переяслав          0.0   202.8     152.2      126.6   115.2     118.8
# Сквира           202.6     0.0     138.7      144.5   111.8     134.7
# Кагарлик         153.1   138.8       0.0       40.2    89.9      48.3
# Миронівка        126.4   142.1      40.2        0.0   118.2      76.6
# Боярка           115.4   110.8      91.3      119.5     0.0      57.8
# Українка         119.5   135.5      48.4       76.6    56.7       0.0

# %% [markdown]
#   ## Крок 2: VRP Оптимізація
#
#
#
#   **Задача:** Розподілити всі замовлення між наявними вантажівками так, щоб мінімізувати загальний час у дорозі, враховуючи обмеження (місткість, часові вікна).
#
#
#
#   **Інструмент:** **VROOM (Vehicle Routing Open-source Optimization Machine)**. Це високопродуктивний оптимізатор, написаний на C++, який вирішує складні варіанти VRP. Ми будемо спілкуватися з ним через простий REST API.

# %%
# =============================================================================
# КОНФІГ
# =============================================================================
import os, json
import numpy as np
import pandas as pd
import requests
from datetime import timedelta
from typing import Optional, Dict, Any, List

OSRM_URL   = os.getenv("OSRM_URL",   "http://139.162.190.110:5000")
VROOM_URL  = os.getenv("VROOM_URL",  "http://139.162.190.110:3010/")   # корінь "/", не /optimize
PROFILE    = os.getenv("VROOM_PROFILE", "car")  # має збігатись з name у config.yml vroom-express

# Допоміжна функія
def time_to_seconds(t: str) -> int:
    """Очікує 'HH:MM' або 'HH:MM:SS'."""
    parts = list(map(int, str(t).split(":")))
    if len(parts) == 2:
        h, m = parts; s = 0
    else:
        h, m, s = parts
    return h*3600 + m*60 + s

# =============================================================================
# Клітинка 3: Запит до OSRM для отримання матриці
# =============================================================================
def get_osrm_matrix(points: pd.DataFrame):
    """
    Отримує матриці тривалостей та дистанцій з OSRM Table API.
    Очікує колонки 'lon', 'lat', 'name' у points.
    """
    # Формуємо список "lon,lat;lon,lat;..."
    coords = ";".join([f"{float(lon)},{float(lat)}" for lon, lat in points[['lon', 'lat']].values])
    url = f"{OSRM_URL}/table/v1/driving/{coords}?annotations=duration,distance"

    try:
        r = requests.get(url, timeout=60)
        r.raise_for_status()
        data = r.json()

        if data.get('code') == 'Ok':
            print("✅ Матрицю відстаней та часу успішно отримано від OSRM.")
            durations = np.array(data['durations'])
            distances = np.array(data['distances'])

            # Базова перевірка
            n = len(points)
            if durations.shape != (n, n) or distances.shape != (n, n):
                raise ValueError(f"Очікувались матриці {n}x{n}, отримано "
                                 f"{durations.shape} і {distances.shape}")
            if np.isnan(durations).any() or np.isinf(durations).any():
                raise ValueError("Матриця durations містить NaN/Inf")

            return durations, distances
        else:
            print(f"❌ Помилка OSRM: {data.get('message', data)}")
            return None, None

    except requests.exceptions.RequestException as e:
        print(f"❌ Не вдалося підключитися до OSRM: {e}")
        print("   Переконайтеся, що контейнери OSRM/VROOM запущені та URL коректні.")
        return None, None

# Об'єднуємо всі точки для запиту до OSRM
all_points = pd.concat([depots_df, jobs_df], ignore_index=True)
durations_matrix, distances_matrix = get_osrm_matrix(all_points)

if durations_matrix is not None:
    durations_df = pd.DataFrame(
        durations_matrix / 60.0,
        index=all_points['name'],
        columns=all_points['name']
    )
    print("\nМатриця часу в дорозі (хвилини):")
    print(durations_df.round(1))
# Out:
# ✅ Матрицю відстаней та часу успішно отримано від OSRM.
#
# Матриця часу в дорозі (хвилини):
# name         Київ-Центр  Бровари  Вишневе  Фастів  Васильків  Обухів  Бориспіль  Ірпінь   Буча  Вишгород  Біла Церква  \
# name
# Київ-Центр          0.0     37.8     26.6    72.5       43.4    48.4       42.4    35.1   40.1      31.1         74.2
# Бровари            34.7      0.0     57.0    99.2       70.1    70.7       24.9    69.8   74.3      54.6        100.9
# Вишневе            28.1     57.9      0.0    68.1       38.9    52.7       56.2    30.1   35.2      44.6         69.7
# Фастів             75.0     99.7     70.7     0.0       39.9    71.8       97.9    77.0   79.6      98.2         35.8
# Васильків          47.1     71.8     42.9    39.9        0.0    35.5       70.0    62.4   67.4      70.3         42.0
# Обухів             50.3     72.3     56.3    72.0       35.7     0.0       68.1    75.9   80.9      76.6         73.4
# Бориспіль          41.8     25.5     56.4    98.6       69.5    66.5        0.0    73.4   78.4      66.7        100.3
# Ірпінь             37.0     71.1     28.6    78.5       60.9    73.3       74.4     0.0    6.7      37.0         91.7
# Буча               41.6     74.8     33.6    79.6       65.9    78.3       79.4     6.9    0.0      37.2         96.7
# Вишгород           29.6     56.4     43.2    98.7       69.5    75.8       66.5    37.3   37.2       0.0        100.3
# Біла Церква        77.7    102.4     73.5    36.4       43.0    72.6      100.7    93.0   98.0     100.9          0.0
# Переяслав          90.9     72.2    105.5   147.7      118.6   115.6       50.3   122.4  127.5     115.8        149.3
# Сквира            130.7    155.4    126.4    75.3       96.0   125.6      153.6   146.0  151.0     153.9         57.9
# Кагарлик           86.3    108.3     92.4   104.2       67.9    44.4      104.1   111.9  116.9     112.7         84.7
# Миронівка         114.5    136.5    120.6   122.1       96.1    72.6      132.3   140.1  145.1     140.9         88.0
# Боярка             40.8     68.1     17.1    55.8       26.9    46.9       66.4    40.8   46.1      58.9         57.4
# Українка           52.7     74.6     59.1    85.2       48.8    20.3       70.4    78.6   83.6      79.0         82.1
#
# name         Переяслав  Сквира  Кагарлик  Миронівка  Боярка  Українка
# name
# Київ-Центр        91.5   127.6      85.0      113.3    38.3      51.6
# Бровари           71.7   154.3     107.3      135.5    66.8      73.9
# Вишневе          105.2   123.1      89.3      117.6    17.1      55.9
# Фастів           146.9    75.2     104.0      123.0    56.1      82.2
# Васильків        119.1    95.4      67.7       96.0    28.5      48.8
# Обухів           117.1   126.8      44.3       72.6    46.8      20.4
# Бориспіль         50.3   153.7     103.1      131.4    66.1      69.7
# Ірпінь           123.5   145.1     109.9      138.2    40.8      76.5
# Буча             128.5   150.1     114.9      143.2    45.8      81.5
# Вишгород         115.6   153.7     112.4      140.7    57.6      79.0
# Біла Церква      149.7    55.4      85.2       89.8    58.8      81.7
# Переяслав          0.0   202.8     152.2      126.6   115.2     118.8
# Сквира           202.6     0.0     138.7      144.5   111.8     134.7
# Кагарлик         153.1   138.8       0.0       40.2    89.9      48.3
# Миронівка        126.4   142.1      40.2        0.0   118.2      76.6
# Боярка           115.4   110.8      91.3      119.5     0.0      57.8
# Українка         119.5   135.5      48.4       76.6    56.7       0.0

# %%
# =============================================================================
# Клітинка 4: Формування запиту до VROOM та його відправка (з індексами)
# =============================================================================
def solve_vrp_with_vroom(depots, jobs, time_matrix):
    """Формує та відправляє запит до VROOM з кастомною матрицею + індексами."""
    PROFILE = "car"
    VROOM_URL = "http://139.162.190.110:3010/"  # root path

    depots = depots.reset_index(drop=True)
    jobs = jobs.reset_index(drop=True)

    n_depots = len(depots)
    n_jobs = len(jobs)
    N = n_depots + n_jobs

    # --- Валідація матриці ---
    if not isinstance(time_matrix, np.ndarray):
        raise ValueError("time_matrix має бути numpy.ndarray")
    if time_matrix.shape != (N, N):
        raise ValueError(f"Очікується матриця {N}x{N}, отримано {time_matrix.shape}")
    if np.isnan(time_matrix).any() or np.isinf(time_matrix).any():
        raise ValueError("Матриця містить NaN/Inf")

    # VROOM любить int секунди
    durations_int = time_matrix.astype(int)

    # --- 0) locations у тій самій послідовності, що й матриця: депо -> jobs ---
    locations = []
    for _, d in depots.iterrows():
        locations.append([float(d["lon"]), float(d["lat"])])
    for _, j in jobs.iterrows():
        locations.append([float(j["lon"]), float(j["lat"])])

    # --- 1) Vehicles (використовуємо індекси замість (або поряд із) координатами) ---
    capacities = [20, 30, 25][:n_depots]  # приклад; підлаштуй під себе
    vehicles = []
    for i, d in depots.iterrows():
        vehicles.append({
            "id": i,
            "profile": PROFILE,
            # координати можна лишити, але головне — індекси:
            "start": [float(d["lon"]), float(d["lat"])],
            "end":   [float(d["lon"]), float(d["lat"])],
            "start_index": i,            # 0..n_depots-1
            "end_index":   i,            # той самий склад як фініш
            "capacity": [int(capacities[i])],
            "time_window": [
                time_to_seconds(str(d["time_window_start"])),
                time_to_seconds(str(d["time_window_end"]))
            ]
        })

    # --- 2) Jobs (location_index = n_depots + j) ---
    vroom_jobs = []
    for j, row in jobs.iterrows():
        vroom_jobs.append({
            "id": n_depots + j,
            # координати можна лишити для читабельності:
            "location": [float(row["lon"]), float(row["lat"])],
            "location_index": n_depots + j,
            "service": int(row.get("service", 900)),  # 15 хв
            "amount": [int(row.get("demand", 1))],
            "time_windows": [[
                time_to_seconds(str(row["time_window_start"])),
                time_to_seconds(str(row["time_window_end"]))
            ]]
        })

    # --- 3) Payload з matrices + locations + індекси ---
    request_payload = {
        "locations": locations,
        "vehicles": vehicles,
        "jobs": vroom_jobs,
        "matrices": {
            PROFILE: {
                "durations": durations_int.tolist()
                # (опційно) можна додати "distances": <така сама NxN> якщо треба
            }
        }
    }

    # --- 4) Відправка ---
    try:
        response = requests.post(
            VROOM_URL,
            json=request_payload,
            timeout=60
        )
        # покидаємо зміст помилки, якщо не 2xx
        try:
            data = response.json()
        except Exception:
            response.raise_for_status()
            data = None

        response.raise_for_status()

        if data is None:
            print("❌ Порожня відповідь від VROOM")
            return None

        if data.get("code", 1) != 0:
            print(f"❌ Помилка оптимізації VROOM: {data.get('error', data)}")
            return None

        print("✅ Оптимальне рішення успішно отримано від VROOM.")
        return data

    except requests.HTTPError as e:
        body = e.response.text if e.response is not None else str(e)
        status = e.response.status_code if e.response is not None else "HTTP"
        print(f"❌ {status} помилка: {body}")
        return None
    except requests.RequestException as e:
        print(f"❌ Network/Request error: {e}")
        return None

# --- Запуск як і раніше ---
vroom_solution = solve_vrp_with_vroom(depots_df, jobs_df, durations_matrix)

if vroom_solution:
    summary = vroom_solution['summary']
    routes = vroom_solution['routes']

    print("\n--- Загальна статистика рішення ---")
    print(f"  Вартість (загальний час): {timedelta(seconds=summary.get('cost', 0))}")
    print(f"  Кількість використаних машин: {summary.get('routes', len(routes))}")
    print(f"  Загальний час в дорозі: {timedelta(seconds=summary.get('duration', 0))}")
    print(f"  Час обслуговування: {timedelta(seconds=summary.get('service', 0))}")

    print("\n--- Деталі маршрутів ---")
    for route in routes:
        vehicle_id = route['vehicle']
        depot_name = depots_df.iloc[vehicle_id]['name'] if 'name' in depots_df.columns else f"Depot #{vehicle_id}"
        steps = route.get('steps', [])
        num_stops = max(0, len(steps) - 2)
        print(f"\n  🚚 Машина #{vehicle_id+1} (зі складу '{depot_name}')")
        if 'delivery' in route and route['delivery']:
            print(f"     - Завантаженість: {route['delivery'][0]} / {capacities[vehicle_id]} од.")
        print(f"     - Кількість доставок: {num_stops}")
        print(f"     - Час у дорозі: {timedelta(seconds=route.get('duration', 0))}")
# Out:
# ✅ Оптимальне рішення успішно отримано від VROOM.
#
# --- Загальна статистика рішення ---
#   Вартість (загальний час): 10:53:26
#   Кількість використаних машин: 3
#   Загальний час в дорозі: 10:53:26
#   Час обслуговування: 2:45:00
#
# --- Деталі маршрутів ---
#
#   🚚 Машина #1 (зі складу 'Київ-Центр')
#      - Завантаженість: 20 / 20 од.
#      - Кількість доставок: 3
#      - Час у дорозі: 3:00:03
#
#   🚚 Машина #2 (зі складу 'Бровари')
#      - Завантаженість: 30 / 30 од.
#      - Кількість доставок: 5
#      - Час у дорозі: 5:56:12
#
#   🚚 Машина #3 (зі складу 'Вишневе')
#      - Завантаженість: 23 / 25 од.
#      - Кількість доставок: 3
#      - Час у дорозі: 1:57:11

# %% [markdown]
#   ## Крок 3: Візуалізація та Аналітика
#
#
#
#   **Задача:** Представити отримані маршрути у зрозумілому вигляді та проаналізувати ключові метрики ефективності.
#
#
#
#   **Інструменти:**
#
#   - **Folium:** Для створення інтерактивних карт на основі Leaflet.js.
#
#   - **Pandas:** Для агрегації та аналізу даних.

# %%
# =============================================================================
# Клітинка 5: Візуалізація маршрутів на інтерактивній карті (без геометрії VROOM)
# =============================================================================
import folium
from datetime import timedelta

def _format_hhmm(seconds: int) -> str:
    td = timedelta(seconds=int(seconds))
    # показуємо як ГГ:ХХ (без днів)
    total_min = int(td.total_seconds() // 60)
    hh, mm = divmod(total_min, 60)
    return f"{hh:02d}:{mm:02d}"

def visualize_routes_on_map(solution, depots: pd.DataFrame, jobs: pd.DataFrame):
    """Візуалізує маршрути з відповіді VROOM, використовуючи індекси та власні координати."""
    if not solution or "routes" not in solution:
        print("Немає даних для візуалізації.")
        return None

    # 0) Формуємо список all_points (у ТІЙ же послідовності, що й для матриці): депо -> jobs
    depots = depots.reset_index(drop=True)
    jobs   = jobs.reset_index(drop=True)
    all_points = pd.concat([depots, jobs], ignore_index=True)

    # 1) Карта
    # Центр — середнє по всіх точках (щоб не прив’язуватись лише до Києва)
    if len(all_points) > 0:
        map_center = [all_points["lat"].mean(), all_points["lon"].mean()]
    else:
        map_center = [50.4501, 30.5234]  # дефолт: Київ
    m = folium.Map(location=map_center, zoom_start=9, tiles="cartodbpositron")

    # 2) Кольори для різних маршрутів
    colors = ['#FF5733', '#33AA55', '#3357FF', '#FF33A1', '#A133FF', '#00A3A3', '#B8860B', '#1E90FF']

    # 3) Депо (іконки)
    for i, depot in depots.iterrows():
        folium.Marker(
            location=[float(depot['lat']), float(depot['lon'])],
            popup=folium.Popup(
                f"<strong>Склад:</strong> {depot.get('name', f'Depot #{i}')}<br>"
                f"Вікно: {depot.get('time_window_start','?-?-?')}–{depot.get('time_window_end','?-?-?')}",
                max_width=300
            ),
            icon=folium.Icon(color='black', icon='home', prefix='fa')
        ).add_to(m)

    # 4) Малюємо кожен маршрут
    for i, route in enumerate(solution["routes"]):
        color = colors[i % len(colors)]
        vid = route["vehicle"]
        steps = route.get("steps", [])

        # Будуємо послідовність координат: для start/end беремо індекси з vehicles-налаштувань,
        # але у відповіді VROOM їх немає. Втім, можна відновити:
        #  - start/end: це індекс складу = vid (бо ми так будували), тобто 0..n_depots-1
        #  - job крок: має ключ 'job' == n_depots + j
        n_depots = len(depots)

        poly_coords = []
        for step in steps:
            stype = step["type"]
            if stype == "start":
                idx = vid  # start_index дорівнює i-го складу
            elif stype == "end":
                idx = vid  # end_index теж той самий склад
            elif stype == "job":
                # step['job'] == n_depots + j
                idx = int(step["job"])
            else:
                # на всяк випадок: пропускаємо невідомі типи
                continue

            # Витягуємо координати з all_points за індексом
            lat = float(all_points.iloc[idx]["lat"])
            lon = float(all_points.iloc[idx]["lon"])
            poly_coords.append([lat, lon])

        # Лінія маршруту
        if len(poly_coords) >= 2:
            folium.PolyLine(
                locations=poly_coords,
                color=color,
                weight=5,
                opacity=0.85,
                popup=f"Машина #{vid + 1}"
            ).add_to(m)

        # Точки доставки з попапами
        for step in steps:
            if step["type"] != "job":
                continue
            job_global_id = int(step["job"])       # n_depots + j
            j_local = job_global_id - n_depots     # індекс в jobs
            if not (0 <= j_local < len(jobs)):
                continue

            row = jobs.iloc[j_local]
            lat = float(row["lat"])
            lon = float(row["lon"])

            # час прибуття — це seconds від старту маршруту
            arr = step.get("arrival", 0)
            arr_hhmm = _format_hhmm(arr)

            # для зручності
            name = row.get("name", f"Job #{job_global_id}")
            tw_s = row.get("time_window_start", "?")
            tw_e = row.get("time_window_end", "?")
            demand = row.get("demand", "?")

            folium.CircleMarker(
                location=[lat, lon],
                radius=7,
                color=color,
                fill=True,
                fill_color=color,
                fill_opacity=0.9,
                popup=folium.Popup(
                    f"<strong>{name}</strong><br>"
                    f"Прибуття (t+): {arr_hhmm}<br>"
                    f"Вікно: {tw_s}–{tw_e}<br>"
                    f"Попит: {demand}",
                    max_width=300
                )
            ).add_to(m)

    print("✅ Інтерактивну карту з маршрутами згенеровано. Файл буде збережено як HTML.")
    return m

# Генеруємо та показуємо мапу
if vroom_solution:
    routes_map = visualize_routes_on_map(vroom_solution, depots_df, jobs_df)
    if routes_map is not None:
        routes_map.save("logistics_routes_map.html")
        display(routes_map)
# Out:
# ✅ Інтерактивну карту з маршрутами згенеровано. Файл буде збережено як HTML.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec942f612ec2149ad5c2615b61ad7dc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec942f612ec2149ad5c2615b61ad7dc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec942f612ec2149ad5c2615b61ad7dc0 = L.map(
#                 &quot;map_ec942f612ec2149ad5c2615b61ad7dc0&quot;,
#                 {
#                     center: [50.196029411764705, 30.503458823529414],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_272da16ae25c59ddcf16372888347a63 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_272da16ae25c59ddcf16372888347a63.addTo(map_ec942f612ec2149ad5c2615b61ad7dc0);
#
#
#             var marker_35e8e4e4bf0ea3fcf1ba7c6a914b343e = L.marker(
#                 [50.4501, 30.5234],
#                 {
# }
#             ).addTo(map_ec942f612ec2149ad5c2615b61ad7dc0);
#
#
#             var icon_230a30ef66e3a73169fce423758b9e6b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_53c73c4ba25417e52d421d9a36f93342 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_9d71d24294eb788502db705aa75fa013 = $(`&lt;div id=&quot;html_9d71d24294eb788502db705aa75fa013&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Склад:&lt;/strong&gt; Київ-Центр&lt;br&gt;Вікно: 09:00–18:00&lt;/div&gt;`)[0];
#                 popup_53c73c4ba25417e52d421d9a36f93342.setContent(html_9d71d24294eb788502db705aa75fa013);
#
#
#
#         marker_35e8e4e4bf0ea3fcf1ba7c6a914b343e.bindPopup(popup_53c73c4ba25417e52d421d9a36f93342)
#         ;
#
#
#
#
#                 marker_35e8e4e4bf0ea3fcf1ba7c6a914b343e.setIcon(icon_230a30ef66e3a73169fce423758b9e6b);
#
#
#             var marker_c5f658b911f3af24a42ad43d341db255 = L.marker(
#                 [50.5116, 30.8357],
#                 {
# }
#             ).addTo(map_ec942f612ec2149ad5c2615b61ad7dc0);
#
#
#             var icon_63ff262df53a7969ca1cf012612e6921 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bad32849c5e9a1aeb0c6fa1a43f78ecb = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_0c3fc2443afe9862b9edfae192587fca = $(`&lt;div id=&quot;html_0c3fc2443afe9862b9edfae192587fca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Склад:&lt;/strong&gt; Бровари&lt;br&gt;Вікно: 09:00–18:00&lt;/div&gt;`)[0];
#                 popup_bad32849c5e9a1aeb0c6fa1a43f78ecb.setContent(html_0c3fc2443afe9862b9edfae192587fca);
#
#
#
#         marker_c5f658b911f3af24a42ad43d341db255.bindPopup(popup_bad32849c5e9a1aeb0c6fa1a43f78ecb)
#         ;
#
#
#
#
#                 marker_c5f658b911f3af24a42ad43d341db255.setIcon(icon_63ff262df53a7969ca1cf012612e6921);
#
#
#             var marker_95a1701810b487e61271dfc18febd29d = L.marker(
#                 [50.3951, 30.3621],
#                 {
# }
#             ).addTo(map_ec942f612ec2149ad5c2615b61ad7dc0);
#
#
#             var icon_9ad269e85c58c1b1402d5a7d407615f1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cedf371ee2ba3466972bdf8d40dcb325 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_824a10f50da10289a1ebcd577fcfcc1e = $(`&lt;div id=&quot;html_824a10f50da10289a1ebcd577fcfcc1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Склад:&lt;/strong&gt; Вишневе&lt;br&gt;Вікно: 09:00–18:00&lt;/div&gt;`)[0];
#                 popup_cedf371ee2ba3466972bdf8d40dcb325.setContent(html_824a10f50da10289a1ebcd577fcfcc1e);
#
#
#
#         marker_95a1701810b487e61271dfc18febd29d.bindPopup(popup_cedf371e

# %% [markdown]
#   ## Системне мислення: від алгоритму до Production
#
#
#
#   Ми щойно виконали основний цикл оптимізації. У реальній продакшн-системі це лише один з багатьох компонентів.
#
#
#
#   - **Дані:** Замість CSV, дані надходили б з бази даних (PostgreSQL + PostGIS).
#
#   - **Сервіси:** OSRM та VROOM працювали б як окремі мікросервіси, які можна масштабувати незалежно.
#
#   - **API:** Наш Python-скрипт був би обгорнутий у FastAPI, приймаючи нові замовлення та повертаючи маршрути.
#
#   - **Оркестрація:** Щоденна пакетна оптимізація запускалася б за розкладом за допомогою Apache Airflow.
#
#   - **Реальний час:** Нові замовлення "на льоту" додавалися б до існуючих маршрутів, викликаючи часткову переоптимізацію.
#
#
#
#   Розуміння того, як окремі алгоритми вписуються в загальну архітектуру, є ключовим для побудови складних та ефективних систем.

# %% [markdown]
#   ## Висновки воркшопу
#
#
#
#   1. **Ми побудували повний пайплайн логістичної оптимізації**, використовуючи інструменти індустріального рівня.
#
#   2. **Побачили силу спеціалізованих алгоритмів:** Contraction Hierarchies (в OSRM) для миттєвого розрахунку відстаней та просунуті евристики (в VROOM) для вирішення складної NP-hard задачі VRP.
#
#   3. **Створили практичний результат:** Інтерактивну карту з оптимальними маршрутами, яку можна показати менеджеру чи водієві.
#
#   4. **Зрозуміли місце алгоритмів у системі:** Наш воркшоп — це "серце" великої логістичної платформи.

# %% [markdown]
#   # Розділ 2: Від Алгоритму до Системи
#
#
#
#   Ми успішно вирішили конкретну задачу оптимізації. Тепер давайте зробимо крок назад і подивимося, як подібні рішення інтегруються в складні продакшн-системи, які використовуються в компаніях рівня Uber, Amazon чи Glovo.

# %% [markdown]
#   ## Архітектура Реальної Production Системи
#
#
#
#   Наш воркшоп — це "серце" оптимізації. У реальному світі воно оточене десятками інших сервісів, які забезпечують збір даних, взаємодію з користувачами, моніторинг та масштабування.
#
#
#
#   ```mermaid
#
#   flowchart TD
#
#       subgraph "Frontend Layer"
#
#           WebApp[Web UI для диспетчерів]
#
#           MobileApp[Мобільний додаток для водіїв]
#
#           Dashboard[Дашборд аналітики]
#
#       end
#
#
#
#       subgraph "Backend Services (Microservices)"
#
#           APIGateway[API Gateway]
#
#           OrderService[Сервіс Замовлень]
#
#           OptimizationService[Наш воркшоп: Сервіс Оптимізації]
#
#           NotificationService[Сервіс Повідомлень]
#
#           UserService[Сервіс Користувачів]
#
#       end
#
#
#
#       subgraph "Routing & Optimization Engines"
#
#           OSRM[OSRM Engine]
#
#           VROOM[VROOM Engine]
#
#       end
#
#
#
#       subgraph "Data Layer"
#
#           Postgres[PostgreSQL + PostGIS]
#
#           Redis[Redis Cache]
#
#           Kafka[Kafka Event Stream]
#
#       end
#
#
#
#       Frontend Layer --> APIGateway
#
#       APIGateway --> OrderService
#
#       APIGateway --> UserService
#
#       OrderService -- надсилає подію --> Kafka
#
#       Kafka -- сповіщає --> OptimizationService
#
#       OptimizationService -- запит матриці --> OSRM
#
#       OptimizationService -- запит оптимізації --> VROOM
#
#       OptimizationService -- зберігає результат --> Postgres
#
#       OptimizationService -- надсилає подію --> Kafka
#
#       Kafka -- сповіщає --> NotificationService
#
#       NotificationService --> MobileApp
#
#       APIGateway -- читає дані --> Postgres
#
#       APIGateway -- читає кеш --> Redis
#
#   ```
#
#
#
#   **Роль наших інструментів у цій архітектурі:**
#
#   - **OSRM/VROOM:** Виділені, незалежні сервіси, які можна масштабувати окремо.
#
#   - **Python-скрипт (наш ноутбук):** Був би обгорнутий у мікросервіс (напр. на FastAPI), який слухає події про нові замовлення з Kafka, викликає OSRM/VROOM, і публікує результат.
#
#   - **PostGIS:** Зберігає гео-дані (координати, полігони зон доставки), що дозволяє робити ефективні просторові запити (напр., "знайти всіх водіїв у радіусі 2 км").

# %% [markdown]
#   ## Системне мислення: Реалії Production
#
#
#
#   | Теорія (що ми зробили) | Реальність (що відбувається в production) | Рішення в Production |
#
#   | :--- | :--- | :--- |
#
#   | **Статичний набір точок** | Нові замовлення надходять постійно, існуючі скасовуються. | **Динамічна переоптимізація:** Запускати VROOM кожні 1-5 хвилин для оновлення маршрутів. |
#
#   | **Ідеальні дані** | Водій застряг у заторі, клієнт не відповідає, GPS-трекер неточний. | **Event-driven архітектура:** Система реагує на події (затримка, скасування) і автоматично запускає перерахунок. |
#
#   | **Один критерій (час)** | Потрібно балансувати час, вартість, завантаженість, пріоритет клієнта, викиди CO₂. | **Багатокритеріальна оптимізація:** Використання вагової функції або пошук Парето-оптимальних рішень. |
#
#   | **Оптимальне рішення** | "Достатньо добре" рішення за 1 секунду набагато цінніше за оптимальне за 10 хвилин. | **Метаевристики та Anytime Algorithms:** Алгоритми, що швидко знаходять хороше рішення і поступово його покращують. |
#
#   | **Надійні сервіси** | OSRM може впасти, VROOM може не знайти рішення. | **Fallback-стратегії:** Якщо VROOM не відповів за 2 секунди, використовувати простішу евристику (напр., призначити найближчого водія). |

# %% [markdown]
#   ## Рефлексія та Обговорення
#
#
#
#   **Питання для закріплення матеріалу:**
#
#
#
#   1.  **Теоретичні:**
#
#       - Чому `Floyd-Warshall` (`O(V³)`), незважаючи на високу складність, корисний для створення матриць відстаней на невеликих графах?
#
#       - Чому `VRP` є `NP-hard` задачею, а пошук найкоротшого шляху (Dijkstra) — ні?
#
#       - Яку структуру даних використовує `PostGIS` для швидкого пошуку "точок у полігоні"? (Відповідь: R-Tree).
#
#
#
#   2.  **Практичні:**
#
#       - Що важливіше для логістичного стартапу: швидкість відповіді API чи оптимальність маршрутів? Як знайти баланс?
#
#       - Як би ви змінили архітектуру для підтримки "батчингу" замовлень (один кур'єр забирає кілька замовлень з одного ресторану)?
#
#       - Які дані потрібно збирати з мобільних додатків водіїв, щоб покращувати модель оптимізації в майбутньому?

# %% [markdown]
#   ## Домашнє Завдання та Подальші Кроки
#
#
#
#   ### Рівень 1: Розширення нашого воркшопу
#
#   1.  **Додайте обмеження по вазі:** Модифікуйте `points.csv`, додавши колонку `weight`. Оновіть VROOM-запит, щоб враховувати не тільки `amount` (об'єм), але й вагу.
#
#   2.  **Додайте пріоритети:** Додайте до замовлень поле `priority` (від 0 до 100). VROOM підтримує це поле "out of the box". Проаналізуйте, як змінилися маршрути.
#
#   3.  **Реалізуйте Fallback:** Напишіть просту Python-функцію, яка реалізує "жадібний" алгоритм (завжди відправляти найближчого вільного водія до найближчого замовлення). Порівняйте результат з VROOM.
#
#
#
#   ### Рівень 2: Новий домен — Таксі-сервіс
#
#   **Задача:** Створити симулятор простого таксі-сервісу.
#
#   1.  **Симуляція:** Напишіть скрипт, який генерує випадкові замовлення (пасажир з точки А в точку Б) кожні 10-30 секунд.
#
#   2.  **Matching:** Для кожного нового замовлення, знайдіть 5 найближчих вільних водіїв (використовуйте OSRM `table` запит).
#
#   3.  **Призначення:** Призначте водія, для якого сумарний час (доїзд до клієнта + поїздка з клієнтом) буде мінімальним.
#
#   4.  **Візуалізація:** Відобразіть на `Folium` мапі рух машин та нові замовлення в реальному часі (можна оновлювати карту в циклі).
#
#
#
#   ### Рівень 3: Дослідження
#
#   - **Прочитайте про алгоритм `Large Neighborhood Search (LNS)`**, який лежить в основі VROOM, і спробуйте написати його спрощену версію.
#
#   - **Дослідіть `OR-Tools` від Google:** Спробуйте вирішити нашу VRP-задачу за допомогою `pywrapcp` бібліотеки і порівняйте результат та складність коду з VROOM.
#
#   - **Проаналізуйте реальні дані:** Завантажте [NYC Taxi Dataset](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page) і побудуйте теплову карту попиту в різний час доби.

# %% [markdown]
#   ## Завершення курсу
#
#
#
#   ### Ключові висновки:
#
#
#
#   1.  **Алгоритми — це інструменти, а не самоціль.** Розуміння задачі та контексту важливіше, ніж знання напам'ять складності кожного алгоритму.
#
#   2.  **Не бійтеся "чорних скриньок".** Такі інструменти, як OSRM та VROOM, є результатом десятиліть досліджень. Ваше завдання як інженера — навчитися їх правильно "готувати" та інтегрувати.
#
#   3.  **Системне мислення вирішує все.** Найкращий алгоритм марний, якщо він не вписаний у надійну, масштабовану та гнучку архітектуру.
#
#
#
#   > **Ви тепер маєте не просто набір знань, а дорожню карту для вирішення складних оптимізаційних задач. Шлях від теорії до практики пройдено. Тепер — час створювати власні системи!**

# %%
# =============================================================================
# Клітинка-довідник: Корисні команди та ресурси
# =============================================================================
print("--- Команди Docker ---")
print("Запустити всі сервіси: docker-compose up -d")
print("Зупинити всі сервіси: docker-compose down")
print("Переглянути логи OSRM: docker logs osrm_backend")
print("Переглянути логи VROOM: docker logs vroom_express")

print("\n--- Корисні посилання ---")
print("OSRM API документація: http://project-osrm.org/docs/v5.27.1/api/")
print("VROOM API документація: https://github.com/VROOM-Project/vroom/blob/master/docs/API.md")
print("OR-Tools VRP (Python): https://developers.google.com/optimization/routing/vrp")
print("Folium документація: https://python-visualization.github.io/folium/")
# Out:
# --- Команди Docker ---
# Запустити всі сервіси: docker-compose up -d
# Зупинити всі сервіси: docker-compose down
# Переглянути логи OSRM: docker logs osrm_backend
# Переглянути логи VROOM: docker logs vroom_express
#
# --- Корисні посилання ---
# OSRM API документація: http://project-osrm.org/docs/v5.27.1/api/
# VROOM API документація: https://github.com/VROOM-Project/vroom/blob/master/docs/API.md
# OR-Tools VRP (Python): https://developers.google.com/optimization/routing/vrp
# Folium документація: https://python-visualization.github.io/folium/
